# %%
# -*- coding: utf-8 -*-
# @Time    : 2021/4/10 18:08
# @Author  : Weiming Mai
# @FileName: main.py
# @Software: PyCharm

import numpy as np
from Nodes import *
from Utils import *
from numpy import *
import xlrd
from sklearn import preprocessing

# %%
# read data
def excel_to_matrix(path, num):
    table = xlrd.open_workbook(path).sheets()[num]  # 获取第一个sheet表
    row = table.nrows  # 行数
    col = table.ncols  # 列数
    datamatrix = np.zeros((row, col))  # 生成一个nrows行ncols列，且元素均为0的初始矩阵
    for x in range(col):
        cols = np.matrix(table.col_values(x))  # 把list转换为矩阵进行矩阵操作
        datamatrix[:, x] = cols  # 按列把数据存进矩阵中
        # 数据归一化
#         min_max_scaler = preprocessing.MinMaxScaler()
#         datamatrix = min_max_scaler.fit_transform(datamatrix)
    return datamatrix

def mini_batch(batch_size, data_X, data_Y):
    idx = np.arange(0, data_X.shape[0])
    np.random.shuffle(idx)
    idx = idx[0:batch_size]

    return data_X[idx,:], data_Y[idx,:]

datafile = "C:/Users/13271/Desktop/git/DL/iris_test+train.xlsx"

data_x = excel_to_matrix(datafile, 0)
data_y = excel_to_matrix(datafile, 3)

x_test = excel_to_matrix(datafile, 1)
y_test = excel_to_matrix(datafile, 2)

# %%
batch_size = 32
x_batch, y_batch = mini_batch(batch_size, data_x, data_y)

x = Input(x_batch)
l2 = Dense(x, 10)
l2 = Sigmoid(l2)
l3 = Dense(l2, 8)
l3 = Sigmoid(l3)
l4 = Dense(l3, 8)
l4 = Sigmoid(l4)
l5 = Dense(l4, 6)
l5 = Sigmoid(l5)
l6 = Dense(l5,4)
l6 = Sigmoid(l6)
l7 = Dense(l6,3)
l7 = Sigmoid(l7)


y = Const(y_batch)
cost = MSE(l7, y)

Forward(cost)
p = Train(cost, [])
GD = G_D_Optimizer(p, 0.001) # lr
print(cost.value)
epoch = 1000
for ep in range(epoch):
    x_batch, y_batch = mini_batch(batch_size, data_x,data_y)
    x.value = x_batch
    y.value = y_batch
    for j in range(30):
        Forward(cost)
        Backprop(cost)
        GD.train()
    if ep % 100 == 0:
        print(cost.value)
#
#test = preprocessing.MinMaxScaler().fit_transform(np.array([[5.1,3.4,1.5,0.2]]))
# x.value = np.array([[5.1,3.4,1.5,0.2]])
# x.value = test
Test(cost)
x.value = x_test
Forward(cost)
# Backprop(cost)
print(cost.value)
print(l7.value)
# Out:
# 0.7676436313279715
# 0.7304482919089375
# 0.66726565013703
# 0.6664390917745138
# 0.6475798428899432
# 0.6624102149943469
# 0.6569421315666527
# 0.6704865235400893
# 0.6656473491813822
# 0.6575973143552931
# 0.6676730695443706
# 0.6445329354396834
# [[0.35553797 0.34580205 0.30025112]
#  [0.35553796 0.34580203 0.30025111]
#  [0.35553792 0.34580195 0.30025107]
#  [0.35553793 0.34580197 0.30025109]
#  [0.35553795 0.34580201 0.3002511 ]
#  [0.35553797 0.34580205 0.30025112]
#  [0.35553794 0.345802   0.30025109]
#  [0.35553797 0.34580206 0.30025113]
#  [0.35553794 0.34580199 0.30025109]
#  [0.35553798 0.34580207 0.30025113]
#  [0.35553796 0.34580203 0.30025111]
#  [0.35553796 0.345802   0.30025106]
#  [0.35553796 0.34580202 0.30025107]
#  [0.35553799 0.34580207 0.30025109]
#  [0.35553797 0.34580204 0.30025108]
#  [0.35553793 0.34580196 0.30025105]
#  [0.35553796 0.34580202 0.30025107]
#  [0.35553797 0.34580205 0.30025108]
#  [0.35553797 0.34580204 0.30025108]
#  [0.355538   0.34580209 0.3002511 ]
#  [0.35553794 0.34580197 0.30025106]
#  [0.35553797 0.34580203 0.30025108]
#  [0.35553801 0.34580211 0.30025109]
#  [0.355538   0.34580207 0.30025107]
#  [0.35553801 0.3458021  0.30025108]
#  [0.35553796 0.345802   0.30025105]
#  [0.35553801 0.34580209 0.30025108]
#  [0.355538   0.34580207 0.30025107]
#  [0.355538   0.34580208 0.30025107]
#  [0.35553798 0.34580205 0.30025106]
#  [0.355538   0.34580208 0.30025108]
#  [0.35553798 0.34580204 0.30025107]
#  [0.35553797 0.34580203 0.30025107]]

# %%
batch_size = 32
x_batch, y_batch = mini_batch(batch_size, data_x, data_y)

x = Input(x_batch)
l2 = Dense(x, 10)
l2 = batch_normalize(l2)
l2 = Sigmoid(l2)
l3 = Dense(l2, 8)
l3 = batch_normalize(l3)
l3 = Sigmoid(l3)
l4 = Dense(l3, 8)
l4 = batch_normalize(l4)
l4 = Sigmoid(l4)
l5 = Dense(l4, 6)
l5 = batch_normalize(l5)
l5 = Sigmoid(l5)
l6 = Dense(l5,4)
l6 = batch_normalize(l6)
l6 = Sigmoid(l6)
l7 = Dense(l6,3)
l7 = batch_normalize(l7)
l7 = Sigmoid(l7)


y = Const(y_batch)
cost = MSE(l7, y)

Forward(cost)
p = Train(cost, [])
GD = G_D_Optimizer(p, 0.1) # lr
print(cost.value)
epoch = 1000
for ep in range(epoch):
    x_batch, y_batch = mini_batch(batch_size, data_x,data_y)
    x.value = x_batch
    y.value = y_batch
    for j in range(10):
        Forward(cost)
        Backprop(cost)
        GD.train()
    if ep % 100 == 0:
        print(cost.value)
#
#test = preprocessing.MinMaxScaler().fit_transform(np.array([[5.1,3.4,1.5,0.2]]))
# x.value = np.array([[5.1,3.4,1.5,0.2]])
# x.value = test
# Test(cost)
x.value = x_test
Forward(cost)
# Backprop(cost)
print(cost.value)
print(l7.value)
# Out:
# 0.7556932615902011
# 0.3331573038607847
# 0.2544070976815476
# 0.17854576066977615
# 0.07307462436710134
# 0.0006439165433503922
# 0.2490996955280117
# 0.030303522318145596
# 0.0016687805728690139
# 0.060760644614317176
# 0.11833903788528434
# 1.3148779598475617
# [[9.98568413e-01 2.92897151e-03 2.24612303e-07]
#  [9.98568478e-01 2.92885983e-03 2.24604024e-07]
#  [9.98568562e-01 2.92871731e-03 2.24593458e-07]
#  [9.98568563e-01 2.92871616e-03 2.24593373e-07]
#  [9.98568375e-01 2.92903581e-03 2.24617071e-07]
#  [9.98568203e-01 2.92932954e-03 2.24638844e-07]
#  [9.98568504e-01 2.92881627e-03 2.24600795e-07]
#  [9.98568367e-01 2.92905044e-03 2.24618155e-07]
#  [9.98568531e-01 2.92876935e-03 2.24597316e-07]
#  [9.98568343e-01 2.92909145e-03 2.24621195e-07]
#  [9.98568466e-01 2.92888184e-03 2.24605656e-07]
#  [4.70472831e-03 9.72720810e-01 2.46508441e-03]
#  [4.71334513e-03 9.72774610e-01 2.45736565e-03]
#  [4.71126915e-03 9.72761457e-01 2.45922984e-03]
#  [4.70680046e-03 9.72733790e-01 2.46322383e-03]
#  [4.70859195e-03 9.72746728e-01 2.46147352e-03]
